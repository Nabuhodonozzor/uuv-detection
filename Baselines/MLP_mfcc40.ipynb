# %% [markdown]
# # Compact MLP Baseline: MFCC-40
# Trains multilabel and binary UUV MLP baselines for normal, M-filtered, and W-filtered MFCC-40 data. Use a T4 GPU runtime.

# %%
import sys
from pathlib import Path

REPO_RAW_BASE_URL = "https://raw.githubusercontent.com/Nabuhodonozzor/uuv-detection/main"
COMMON_UTILS_FILE = "common_utils.py"
MODEL_UTILS_FILE = "mlp_utils.py"
MODEL_DIR = "Baselines"
common_dirs = [Path.cwd() / "utils", Path.cwd().parent / "utils", Path("/content/utils"), Path("/content/drive/MyDrive/STUDA/src/utils")]
model_dirs = [Path.cwd(), Path.cwd() / MODEL_DIR, Path.cwd().parent / MODEL_DIR, Path("/content") / MODEL_DIR, Path("/content/drive/MyDrive/STUDA/src") / MODEL_DIR]
common_dir = next((directory for directory in common_dirs if (directory / COMMON_UTILS_FILE).exists()), None)
model_dir = next((directory for directory in model_dirs if (directory / MODEL_UTILS_FILE).exists()), None)

if common_dir is None or model_dir is None:
    import urllib.request
    common_dir = Path("/content/utils")
    model_dir = Path("/content") / MODEL_DIR
    common_dir.mkdir(parents=True, exist_ok=True)
    model_dir.mkdir(parents=True, exist_ok=True)
    urllib.request.urlretrieve(f"{REPO_RAW_BASE_URL}/utils/{COMMON_UTILS_FILE}", common_dir / COMMON_UTILS_FILE)
    urllib.request.urlretrieve(f"{REPO_RAW_BASE_URL}/{MODEL_DIR}/{MODEL_UTILS_FILE}", model_dir / MODEL_UTILS_FILE)

sys.path.insert(0, str(common_dir))
sys.path.insert(0, str(model_dir))
print(f"Using common utilities from: {common_dir}")
print(f"Using baseline utilities from: {model_dir}")
# Out:
# Using common utilities from: /content/utils
# Using baseline utilities from: /content/Baselines

# %%
import pandas as pd
from IPython.display import display
from google.colab import files

from common_utils import configure_kaggle_access, evaluate_models_for_variants, extract_zip, plot_training_histories, prepare_mfcc_dataset_variants, save_keras_artifacts, train_keras_models_for_variants, zip_artifacts
from mlp_utils import build_mlp_models_for_variants, get_mlp_callbacks

# %%
DATASET_KEY = "mfcc40"
DATASET_LABEL = "MFCC-40"
DATASET_SLUG = "pawedyrda/mfcc12"
ARCHIVE_PATH = Path("/content/mfcc12.zip")
EPOCHS = 50
BATCH_SIZE = 64

# %%
configure_kaggle_access("Kaggle")
if not ARCHIVE_PATH.exists():
    # !kaggle datasets download -d {DATASET_SLUG} -p /content
else:
    print(f"Reusing downloaded archive: {ARCHIVE_PATH}")
DATA_PATH = extract_zip(ARCHIVE_PATH, "/content")
print(f"Dataset extracted to: {DATA_PATH}")
# Out:
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2)
# Dataset URL: https://www.kaggle.com/datasets/pawedyrda/mfcc12
# License(s): unknown
# Downloading mfcc12.zip to /content
# 100% 837M/837M [00:50<00:00, 17.4MB/s]
#
# Dataset extracted to: /content/mfcc12

# %%
variants = prepare_mfcc_dataset_variants(DATA_PATH)
print("Normal train shape:", variants.normal.train_data.shape)
print("M train shape:", variants.m.train_data.shape)
print("W train shape:", variants.w.train_data.shape)
# Out:
# Scanning feature data in: /content/mfcc12
# Found .npz files: 9527, skipped: 0
# Loaded samples: 9527
# X shape: (9527, 618, 40)
# y shape: (9527, 17)
# Scanning feature data in: /content/mfcc12 (UUV filter: M)
# Found .npz files: 9527, skipped: 523
# Loaded samples: 9004
# X shape: (9004, 618, 40)
# y shape: (9004, 17)
# Scanning feature data in: /content/mfcc12 (UUV filter: W)
# Found .npz files: 9527, skipped: 379
# Loaded samples: 9148
# X shape: (9148, 618, 40)
# y shape: (9148, 17)
# Normal train shape: (6096, 618, 40)
# M train shape: (5762, 618, 40)
# W train shape: (5854, 618, 40)

# %%
multilabel_models = build_mlp_models_for_variants(variants, model_type="multilabel")
multilabel_histories = train_keras_models_for_variants(multilabel_models, variants, "multilabel", EPOCHS, BATCH_SIZE, get_mlp_callbacks)
plot_training_histories(multilabel_histories, f"MLP multilabel training: {DATASET_LABEL}")

binary_models = build_mlp_models_for_variants(variants, model_type="binary")
binary_histories = train_keras_models_for_variants(binary_models, variants, "binary", EPOCHS, BATCH_SIZE, get_mlp_callbacks)
plot_training_histories(binary_histories, f"MLP binary training: {DATASET_LABEL}")
# Out:
# Training multilabel model for variant: normal
# Epoch 1/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - binary_accuracy: 0.9031 - loss: 0.2933 - pr_auc: 0.1943 - precision: 0.4340 - recall: 0.4507 - roc_auc: 0.7142 - val_binary_accuracy: 0.9447 - val_loss: 0.1433 - val_pr_auc: 0.5331 - val_precision: 0.7955 - val_recall: 0.4998 - val_roc_auc: 0.9184 - learning_rate: 0.0010
# Epoch 2/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9382 - loss: 0.1597 - pr_auc: 0.4038 - precision: 0.6640 - recall: 0.5558 - roc_auc: 0.8767 - val_binary_accuracy: 0.9507 - val_loss: 0.1191 - val_pr_auc: 0.6937 - val_precision: 0.7955 - val_recall: 0.5918 - val_roc_auc: 0.9532 - learning_rate: 0.0010
# Epoch 3/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9484 - loss: 0.1291 - pr_auc: 0.5145 - precision: 0.7389 - recall: 0.6106 - roc_auc: 0.9313 - val_binary_accuracy: 0.9559 - val_loss: 0.1085 - val_pr_auc: 0.7261 - val_precision: 0.8159 - val_recall: 0.6449 - val_roc_auc: 0.9619 - learning_rate: 0.0010
# Epoch 4/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9531 - loss: 0.1144 - pr_auc: 0.5921 - precision: 0.7567 - recall: 0.6633 - roc_auc: 0.9515 - val_binary_accuracy: 0.9557 - val_loss: 0.1063 - val_pr_auc: 0.7432 - val_precision: 0.8362 - val_recall: 0.6177 - val_roc_auc: 0.9657 - learning_rate: 0.0010
# Epoch 5/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9579 - loss: 0.1012 - pr_auc: 0.6666 - precision: 0.7864 - recall: 0.6951 - roc_auc: 0.9650 - val_binary_accuracy: 0.9570 - val_loss: 0.1013 - val_pr_auc: 0.7779 - val_precision: 0.8466 - val_recall: 0.6243 - val_roc_auc: 0.9709 - learning_rate: 0.0010
# Epoch 6/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9621 - loss: 0.0902 - pr_auc: 0.7314 - precision: 0.8087 - recall: 0.7276 - roc_auc: 0.9734 - val_binary_accuracy: 0.9598 - val_loss: 0.0968 - val_pr_auc: 0.7991 - val_precision: 0.8355 - val_recall: 0.6769 - val_roc_auc: 0.9678 - learning_rate: 0.0010
# Epoch 7/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9644 - loss: 0.0848 - pr_auc: 0.7674 - precision: 0.8150 - recall: 0.7529 - roc_auc: 0.9769 - val_binary_accuracy: 0.9611 - val_loss: 0.0908 - val_pr_auc: 0.8207 - val_precision: 0.8926 - val_recall: 0.6339 - val_roc_auc: 0.9754 - learning_rate: 0.0010
# Epoch 8/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - binary_accuracy: 0.9677 - loss: 0.0783 - pr_auc: 0.8089 - precision: 0.8361 - recall: 0.7722 - roc_auc: 0.9813 - val_binary_accuracy: 0.9621 - val_loss: 0.0935 - val_pr_auc: 0.8002 - val_precision: 0.8688 - val_recall: 0.6708 - val_roc_auc: 0.9666 - learning_rate: 0.0010
# Epoch 9/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9702 - loss: 0.0715 - pr_auc: 0.8457 - precision: 0.8478 - recall: 0.7927 - roc_auc: 0.9845 - val_binary_accuracy: 0.9616 - val_loss: 0.0935 - val_pr_auc: 0.8145 - val_precision: 0.8782 - val_recall: 0.6545 - val_roc_auc: 0.9662 - learning_rate: 0.0010
# Epoch 10/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - binary_accuracy: 0.9741 - loss: 0.0637 - pr_auc: 0.8617 - precision: 0.8690 - recall: 0.8196 - roc_auc: 0.9886 - val_binary_accuracy: 0.9632 - val_loss: 0.0952 - val_pr_auc: 0.7964 - val_precision: 0.8726 - val_recall: 0.6817 - val_roc_auc: 0.9563 - learning_rate: 0.0010
# Epoch 11/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9746 - loss: 0.0609 - pr_auc: 0.8816 - precision: 0.8648 - recall: 0.8317 - roc_auc: 0.9892 - val_binary_accuracy: 0.9608 - val_loss: 0.0983 - val_pr_auc: 0.8036 - val_precision: 0.8454 - val_recall: 0.6786 - val_roc_auc: 0.9588 - learning_rate: 0.0010
# Epoch 12/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - binary_accuracy: 0.9777 - loss: 0.0547 - pr_auc: 0.9035 - precision: 0.8836 - recall: 0.8500 - roc_auc: 0.9917 - val_binary_accuracy: 0.9638 - val_loss: 0.0882 - val_pr_auc: 0.8297 - val_precision: 0.8703 - val_recall: 0.6914 - val_roc_auc: 0.9727 - learning_rate: 5.0000e-04
# Epoch 13/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - binary_accuracy: 0.9799 - loss: 0.0505 - pr_auc: 0.9330 - precision: 0.8969 - recall: 0.8637 - roc_auc: 0.9931 - val_binary_accuracy: 0.9635 - val_loss: 0.0921 - val_pr_auc: 0.8114 - val_precision: 0.8662 - val_recall: 0.6927 - val_roc_auc: 0.9675 - learning_rate: 5.0000e-04
# Epoch 14/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9808 - loss: 0.0483 - pr_auc: 0.9297 - precision: 0.8981 - recall: 0.8742 - roc_auc: 0.9936 - val_binary_accuracy: 0.9633 - val_loss: 0.0961 - val_pr_auc: 0.8041 - val_precision: 0.8813 - val_recall: 0.6738 - val_roc_auc: 0.9572 - learning_rate: 5.0000e-04
# Epoch 15/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9813 - loss: 0.0467 - pr_auc: 0.9333 - precision: 0.9015 - recall: 0.8761 - roc_auc: 0.9943 - val_binary_accuracy: 0.9637 - val_loss: 0.0969 - val_pr_auc: 0.7935 - val_precision: 0.8614 - val_recall: 0.7001 - val_roc_auc: 0.9535 - learning_rate: 5.0000e-04
# Epoch 16/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9830 - loss: 0.0434 - pr_auc: 0.9439 - precision: 0.9067 - recall: 0.8919 - roc_auc: 0.9952 - val_binary_accuracy: 0.9628 - val_loss: 0.0981 - val_pr_auc: 0.8011 - val_precision: 0.8611 - val_recall: 0.6879 - val_roc_auc: 0.9532 - learning_rate: 5.0000e-04
# Epoch 17/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9843 - loss: 0.0409 - pr_auc: 0.9514 - precision: 0.9142 - recall: 0.9000 - roc_auc: 0.9956 - val_binary_accuracy: 0.9644 - val_loss: 0.0962 - val_pr_auc: 0.8134 - val_precision: 0.8710 - val_recall: 0.6984 - val_roc_auc: 0.9576 - learning_rate: 2.5000e-04
# Epoch 18/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9850 - loss: 0.0393 - pr_auc: 0.9500 - precision: 0.9171 - recall: 0.9058 - roc_auc: 0.9961 - val_binary_accuracy: 0.9652 - val_loss: 0.0900 - val_pr_auc: 0.8126 - val_precision: 0.8604 - val_recall: 0.7212 - val_roc_auc: 0.9625 - learning_rate: 2.5000e-04
# Epoch 19/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9852 - loss: 0.0384 - pr_auc: 0.9602 - precision: 0.9154 - recall: 0.9101 - roc_auc: 0.9963 - val_binary_accuracy: 0.9634 - val_loss: 0.0964 - val_pr_auc: 0.8052 - val_precision: 0.8584 - val_recall: 0.6988 - val_roc_auc: 0.9556 - learning_rate: 2.5000e-04
# Epoch 20/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9852 - loss: 0.0383 - pr_auc: 0.9561 - precision: 0.9206 - recall: 0.9045 - roc_auc: 0.9964 - val_binary_accuracy: 0.9634 - val_loss: 0.1013 - val_pr_auc: 0.7972 - val_precision: 0.8728 - val_recall: 0.6830 - val_roc_auc: 0.9502 - learning_rate: 2.5000e-04
# Training multilabel model for variant: M
# Epoch 1/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - binary_accuracy: 0.9076 - loss: 0.3169 - pr_auc: 0.1903 - precision: 0.4306 - recall: 0.4558 - roc_auc: 0.7298 - val_binary_accuracy: 0.9462 - val_loss: 0.1390 - val_pr_auc: 0.5233 - val_precision: 0.6693 - val_recall: 0.6816 - val_roc_auc: 0.9206 - learning_rate: 0.0010
# Epoch 2/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9364 - loss: 0.1621 - pr_auc: 0.3739 - precision: 0.6177 - recall: 0.5530 - roc_auc: 0.8780 - val_binary_accuracy: 0.9505 - val_loss: 0.1192 - val_pr_auc: 0.6280 - val_precision: 0.8205 - val_recall: 0.5087 - val_roc_auc: 0.9490 - learning_rate: 0.0010
# Epoch 3/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9473 - loss: 0.1324 - pr_auc: 0.4738 - precision: 0.7050 - recall: 0.5953 - roc_auc: 0.9196 - val_binary_accuracy: 0.9551 - val_loss: 0.1051 - val_pr_auc: 0.7557 - val_precision: 0.7946 - val_recall: 0.6110 - val_roc_auc: 0.9678 - learning_rate: 0.0010
# Epoch 4/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9516 - loss: 0.1183 - pr_auc: 0.5477 - precision: 0.7327 - recall: 0.6293 - roc_auc: 0.9408 - val_binary_accuracy: 0.9567 - val_loss: 0.1039 - val_pr_auc: 0.7459 - val_precision: 0.7838 - val_recall: 0.6538 - val_roc_auc: 0.9645 - learning_rate: 0.0010
# Epoch 5/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9564 - loss: 0.1052 - pr_auc: 0.6365 - precision: 0.7605 - recall: 0.6706 - roc_auc: 0.9567 - val_binary_accuracy: 0.9588 - val_loss: 0.0986 - val_pr_auc: 0.7785 - val_precision: 0.8797 - val_recall: 0.5777 - val_roc_auc: 0.9658 - learning_rate: 0.0010
# Epoch 6/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9610 - loss: 0.0944 - pr_auc: 0.6968 - precision: 0.7879 - recall: 0.7053 - roc_auc: 0.9668 - val_binary_accuracy: 0.9610 - val_loss: 0.0935 - val_pr_auc: 0.7929 - val_precision: 0.8286 - val_recall: 0.6627 - val_roc_auc: 0.9705 - learning_rate: 0.0010
# Epoch 7/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - binary_accuracy: 0.9647 - loss: 0.0849 - pr_auc: 0.7558 - precision: 0.8086 - recall: 0.7361 - roc_auc: 0.9749 - val_binary_accuracy: 0.9632 - val_loss: 0.0917 - val_pr_auc: 0.7982 - val_precision: 0.8470 - val_recall: 0.6736 - val_roc_auc: 0.9702 - learning_rate: 0.0010
# Epoch 8/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - binary_accuracy: 0.9671 - loss: 0.0796 - pr_auc: 0.7765 - precision: 0.8217 - recall: 0.7560 - roc_auc: 0.9772 - val_binary_accuracy: 0.9629 - val_loss: 0.0922 - val_pr_auc: 0.8096 - val_precision: 0.8262 - val_recall: 0.6945 - val_roc_auc: 0.9704 - learning_rate: 0.0010
# Epoch 9/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - binary_accuracy: 0.9697 - loss: 0.0742 - pr_auc: 0.8040 - precision: 0.8343 - recall: 0.7780 - roc_auc: 0.9820 - val_binary_accuracy: 0.9600 - val_loss: 0.1056 - val_pr_auc: 0.7763 - val_precision: 0.8289 - val_recall: 0.6473 - val_roc_auc: 0.9468 - learning_rate: 0.0010
# Epoch 10/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9668 - loss: 0.0822 - pr_auc: 0.7584 - precision: 0.8180 - recall: 0.7562 - roc_auc: 0.9678 - val_binary_accuracy: 0.9604 - val_loss: 0.1028 - val_pr_auc: 0.7619 - val_precision: 0.8174 - val_recall: 0.6672 - val_roc_auc: 0.9492 - learning_rate: 0.0010
# Epoch 11/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9672 - loss: 0.0812 - pr_auc: 0.7693 - precision: 0.8171 - recall: 0.7645 - roc_auc: 0.9757 - val_binary_accuracy: 0.9622 - val_loss: 0.0972 - val_pr_auc: 0.7825 - val_precision: 0.8640 - val_recall: 0.6408 - val_roc_auc: 0.9559 - learning_rate: 0.0010
# Epoch 12/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9735 - loss: 0.0654 - pr_auc: 0.8432 - precision: 0.8538 - recall: 0.8105 - roc_auc: 0.9851 - val_binary_accuracy: 0.9660 - val_loss: 0.0871 - val_pr_auc: 0.8099 - val_precision: 0.8429 - val_recall: 0.7198 - val_roc_auc: 0.9638 - learning_rate: 5.0000e-04
# Epoch 13/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9747 - loss: 0.0604 - pr_auc: 0.8691 - precision: 0.8519 - recall: 0.8302 - roc_auc: 0.9889 - val_binary_accuracy: 0.9658 - val_loss: 0.0881 - val_pr_auc: 0.8235 - val_precision: 0.8696 - val_recall: 0.6860 - val_roc_auc: 0.9660 - learning_rate: 5.0000e-04
# Epoch 14/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9765 - loss: 0.0568 - pr_auc: 0.8891 - precision: 0.8718 - recall: 0.8311 - roc_auc: 0.9907 - val_binary_accuracy: 0.9665 - val_loss: 0.0847 - val_pr_auc: 0.8300 - val_precision: 0.8519 - val_recall: 0.7173 - val_roc_auc: 0.9676 - learning_rate: 5.0000e-04
# Epoch 15/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9764 - loss: 0.0568 - pr_auc: 0.8937 - precision: 0.8651 - recall: 0.8376 - roc_auc: 0.9906 - val_binary_accuracy: 0.9662 - val_loss: 0.0875 - val_pr_auc: 0.8088 - val_precision: 0.8752 - val_recall: 0.6860 - val_roc_auc: 0.9674 - learning_rate: 5.0000e-04
# Epoch 16/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - binary_accuracy: 0.9786 - loss: 0.0520 - pr_auc: 0.9063 - precision: 0.8828 - recall: 0.8473 - roc_auc: 0.9924 - val_binary_accuracy: 0.9666 - val_loss: 0.0870 - val_pr_auc: 0.8132 - val_precision: 0.8649 - val_recall: 0.7029 - val_roc_auc: 0.9602 - learning_rate: 5.0000e-04
# Epoch 17/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9792 - loss: 0.0503 - pr_auc: 0.9022 - precision: 0.8819 - recall: 0.8570 - roc_auc: 0.9927 - val_binary_accuracy: 0.9668 - val_loss: 0.0909 - val_pr_auc: 0.8112 - val_precision: 0.8549 - val_recall: 0.7173 - val_roc_auc: 0.9556 - learning_rate: 5.0000e-04
# Epoch 18/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9813 - loss: 0.0466 - pr_auc: 0.9178 - precision: 0.8930 - recall: 0.8723 - roc_auc: 0.9940 - val_binary_accuracy: 0.9675 - val_loss: 0.0883 - val_pr_auc: 0.8201 - val_precision: 0.8608 - val_recall: 0.7218 - val_roc_auc: 0.9579 - learning_rate: 5.0000e-04
# Epoch 19/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9826 - loss: 0.0431 - pr_auc: 0.9362 - precision: 0.9006 - recall: 0.8812 - roc_auc: 0.9949 - val_binary_accuracy: 0.9678 - val_loss: 0.0879 - val_pr_auc: 0.8272 - val_precision: 0.8705 - val_recall: 0.7144 - val_roc_auc: 0.9597 - learning_rate: 2.5000e-04
# Epoch 20/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9829 - loss: 0.0424 - pr_auc: 0.9297 - precision: 0.8989 - recall: 0.8875 - roc_auc: 0.9950 - val_binary_accuracy: 0.9671 - val_loss: 0.0938 - val_pr_auc: 0.8044 - val_precision: 0.8708 - val_recall: 0.7034 - val_roc_auc: 0.9513 - learning_rate: 2.5000e-04
# Epoch 21/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - binary_accuracy: 0.9834 - loss: 0.0412 - pr_auc: 0.9415 - precision: 0.9043 - recall: 0.8875 - roc_auc: 0.9957 - val_binary_accuracy: 0.9675 - val_loss: 0.0893 - val_pr_auc: 0.8166 - val_precision: 0.8591 - val_recall: 0.7238 - val_roc_auc: 0.9561 - learning_rate: 2.5000e-04
# Epoch 22/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - binary_accuracy: 0.9835 - loss: 0.0413 - pr_auc: 0.9392 - precision: 0.9034 - recall: 0.8903 - roc_auc: 0.9953 - val_binary_accuracy: 0.9677 - val_loss: 0.0930 - val_pr_auc: 0.8044 - val_precision: 0.8708 - val_recall: 0.7129 - val_roc_auc: 0.9518 - learning_rate: 2.5000e-04
# Training multilabel model for variant: W
# Epoch 1/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - binary_accuracy: 0.9039 - loss: 0.2972 - pr_auc: 0.2018 - precision: 0.4301 - recall: 0.4844 - roc_auc: 0.6776 - val_binary_accuracy: 0.9500 - val_loss: 0.1242 - val_pr_auc: 0.5385 - val_precision: 0.7756 - val_recall: 0.5511 - val_roc_auc: 0.8758 - learning_rate: 0.0010
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - binary_accuracy: 0.9387 - loss: 0.1576 - pr_auc: 0.3933 - precision: 0.6506 - recall: 0.5659 - roc_auc: 0.8260 - val_binary_accuracy: 0.9558 - val_loss: 0.1132 - val_pr_auc: 0.6349 - val_precision: 0.8011 - val_recall: 0.6147 - val_roc_auc: 0.8795 - learning_rate: 0.0010
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - binary_accuracy: 0.9487 - loss: 0.1271 - pr_auc: 0.5197 - precision: 0.7180 - recall: 0.6290 - roc_auc: 0.8736 - val_binary_accuracy: 0.9592 - val_loss: 0.0979 - val_pr_auc: 0.7159 - val_precision: 0.8441 - val_recall: 0.6171 - val_roc_auc: 0.9089 - learning_rate: 0.0010
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - binary_accuracy: 0.9553 - loss: 0.1110 - pr_auc: 0.6023 - precision: 0.7625 - recall: 0.6699 - roc_auc: 0.8915 - val_binary_accuracy: 0.9626 - val_loss: 0.0908 - val_pr_auc: 0.7290 - val_precision: 0.8247 - val_recall: 0.6924 - val_roc_auc: 0.9094 - learning_rate: 0.0010
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9584 - loss: 0.0999 - pr_auc: 0.6652 - precision: 0.7804 - recall: 0.6941 - roc_auc: 0.9034 - val_binary_accuracy: 0.9655 - val_loss: 0.0853 - val_pr_auc: 0.7497 - val_precision: 0.8739 - val_recall: 0.6778 - val_roc_auc: 0.9157 - learning_rate: 0.0010
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9641 - loss: 0.0862 - pr_auc: 0.7154 - precision: 0.8147 - recall: 0.7356 - roc_auc: 0.9134 - val_binary_accuracy: 0.9645 - val_loss: 0.0891 - val_pr_auc: 0.7478 - val_precision: 0.8474 - val_recall: 0.6924 - val_roc_auc: 0.9064 - learning_rate: 0.0010
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9687 - loss: 0.0771 - pr_auc: 0.7607 - precision: 0.8387 - recall: 0.7708 - roc_auc: 0.9213 - val_binary_accuracy: 0.9668 - val_loss: 0.0838 - val_pr_auc: 0.7621 - val_precision: 0.8550 - val_recall: 0.7178 - val_roc_auc: 0.9075 - learning_rate: 0.0010
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9708 - loss: 0.0711 - pr_auc: 0.7848 - precision: 0.8505 - recall: 0.7868 - roc_auc: 0.9241 - val_binary_accuracy: 0.9664 - val_loss: 0.0872 - val_pr_auc: 0.7589 - val_precision: 0.8481 - val_recall: 0.7208 - val_roc_auc: 0.9089 - learning_rate: 0.0010
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - binary_accuracy: 0.9722 - loss: 0.0671 - pr_auc: 0.8049 - precision: 0.8538 - recall: 0.8022 - roc_auc: 0.9272 - val_binary_accuracy: 0.9660 - val_loss: 0.0903 - val_pr_auc: 0.7526 - val_precision: 0.8685 - val_recall: 0.6910 - val_roc_auc: 0.8969 - learning_rate: 0.0010
# Epoch 10/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9735 - loss: 0.0637 - pr_auc: 0.8155 - precision: 0.8581 - recall: 0.8162 - roc_auc: 0.9278 - val_binary_accuracy: 0.9664 - val_loss: 0.0881 - val_pr_auc: 0.7440 - val_precision: 0.8334 - val_recall: 0.7389 - val_roc_auc: 0.8989 - learning_rate: 0.0010
# Epoch 11/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9760 - loss: 0.0584 - pr_auc: 0.8382 - precision: 0.8728 - recall: 0.8320 - roc_auc: 0.9309 - val_binary_accuracy: 0.9681 - val_loss: 0.0840 - val_pr_auc: 0.7701 - val_precision: 0.8872 - val_recall: 0.7002 - val_roc_auc: 0.9070 - learning_rate: 0.0010
# Epoch 12/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9800 - loss: 0.0489 - pr_auc: 0.8676 - precision: 0.8962 - recall: 0.8588 - roc_auc: 0.9347 - val_binary_accuracy: 0.9693 - val_loss: 0.0825 - val_pr_auc: 0.7687 - val_precision: 0.8851 - val_recall: 0.7193 - val_roc_auc: 0.9041 - learning_rate: 5.0000e-04
# Epoch 13/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9811 - loss: 0.0481 - pr_auc: 0.8771 - precision: 0.8980 - recall: 0.8708 - roc_auc: 0.9352 - val_binary_accuracy: 0.9671 - val_loss: 0.0885 - val_pr_auc: 0.7601 - val_precision: 0.8799 - val_recall: 0.6949 - val_roc_auc: 0.8909 - learning_rate: 5.0000e-04
# Epoch 14/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - binary_accuracy: 0.9826 - loss: 0.0437 - pr_auc: 0.8846 - precision: 0.9081 - recall: 0.8792 - roc_auc: 0.9364 - val_binary_accuracy: 0.9681 - val_loss: 0.0846 - val_pr_auc: 0.7642 - val_precision: 0.8638 - val_recall: 0.7257 - val_roc_auc: 0.9019 - learning_rate: 5.0000e-04
# Epoch 15/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9830 - loss: 0.0431 - pr_auc: 0.8830 - precision: 0.9111 - recall: 0.8809 - roc_auc: 0.9359 - val_binary_accuracy: 0.9685 - val_loss: 0.0859 - val_pr_auc: 0.7695 - val_precision: 0.8763 - val_recall: 0.7174 - val_roc_auc: 0.8990 - learning_rate: 5.0000e-04
# Epoch 16/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.9843 - loss: 0.0410 - pr_auc: 0.8973 - precision: 0.9153 - recall: 0.8940 - roc_auc: 0.9368 - val_binary_accuracy: 0.9672 - val_loss: 0.0889 - val_pr_auc: 0.7576 - val_precision: 0.8853 - val_recall: 0.6905 - val_roc_auc: 0.8966 - learning_rate: 5.0000e-04
# Epoch 17/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - binary_accuracy: 0.9850 - loss: 0.0380 - pr_auc: 0.9003 - precision: 0.9198 - recall: 0.8982 - roc_auc: 0.9376 - val_binary_accuracy: 0.9680 - val_loss: 0.0881 - val_pr_auc: 0.7628 - val_precision: 0.8801 - val_recall: 0.7071 - val_roc_auc: 0.8970 - learning_rate: 2.5000e-04
# Epoch 18/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9862 - loss: 0.0364 - pr_auc: 0.9042 - precision: 0.9214 - recall: 0.9109 - roc_auc: 0.9377 - val_binary_accuracy: 0.9685 - val_loss: 0.0877 - val_pr_auc: 0.7576 - val_precision: 0.8712 - val_recall: 0.7242 - val_roc_auc: 0.8936 - learning_rate: 2.5000e-04
# Epoch 19/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9857 - loss: 0.0364 - pr_auc: 0.9032 - precision: 0.9218 - recall: 0.9040 - roc_auc: 0.9379 - val_binary_accuracy: 0.9677 - val_loss: 0.0871 - val_pr_auc: 0.7663 - val_precision: 0.8856 - val_recall: 0.6968 - val_roc_auc: 0.8944 - learning_rate: 2.5000e-04
# Epoch 20/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9870 - loss: 0.0342 - pr_auc: 0.9089 - precision: 0.9247 - recall: 0.9182 - roc_auc: 0.9383 - val_binary_accuracy: 0.9687 - val_loss: 0.0885 - val_pr_auc: 0.7580 - val_precision: 0.8809 - val_recall: 0.7164 - val_roc_auc: 0.8940 - learning_rate: 2.5000e-04
# Training binary model for variant: normal
# Epoch 1/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - binary_accuracy: 0.9042 - loss: 0.6527 - pr_auc: 0.3723 - precision: 0.4551 - recall: 0.2839 - roc_auc: 0.8051 - val_binary_accuracy: 0.9482 - val_loss: 0.1517 - val_pr_auc: 0.8090 - val_precision: 0.8646 - val_recall: 0.5570 - val_roc_auc: 0.9669 - learning_rate: 0.0010
# Epoch 2/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9488 - loss: 0.1217 - pr_auc: 0.8272 - precision: 0.9199 - recall: 0.4774 - roc_auc: 0.9696 - val_binary_accuracy: 0.9541 - val_loss: 0.1000 - val_pr_auc: 0.9128 - val_precision: 0.9877 - val_recall: 0.5369 - val_roc_auc: 0.9874 - learning_rate: 0.0010
# Epoch 3/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9619 - loss: 0.0900 - pr_auc: 0.8985 - precision: 0.9235 - recall: 0.6329 - roc_auc: 0.9861 - val_binary_accuracy: 0.9639 - val_loss: 0.0848 - val_pr_auc: 0.9370 - val_precision: 0.9700 - val_recall: 0.6510 - val_roc_auc: 0.9919 - learning_rate: 0.0010
# Epoch 4/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9667 - loss: 0.0754 - pr_auc: 0.9235 - precision: 0.8995 - recall: 0.7125 - roc_auc: 0.9897 - val_binary_accuracy: 0.9633 - val_loss: 0.0791 - val_pr_auc: 0.9380 - val_precision: 0.9604 - val_recall: 0.6510 - val_roc_auc: 0.9914 - learning_rate: 0.0010
# Epoch 5/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9779 - loss: 0.0551 - pr_auc: 0.9569 - precision: 0.9447 - recall: 0.8029 - roc_auc: 0.9954 - val_binary_accuracy: 0.9679 - val_loss: 0.0842 - val_pr_auc: 0.9576 - val_precision: 0.9902 - val_recall: 0.6779 - val_roc_auc: 0.9860 - learning_rate: 0.0010
# Epoch 6/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9828 - loss: 0.0403 - pr_auc: 0.9785 - precision: 0.9498 - recall: 0.8553 - roc_auc: 0.9975 - val_binary_accuracy: 0.9770 - val_loss: 0.0574 - val_pr_auc: 0.9653 - val_precision: 0.9453 - val_recall: 0.8121 - val_roc_auc: 0.9955 - learning_rate: 0.0010
# Epoch 7/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9857 - loss: 0.0339 - pr_auc: 0.9852 - precision: 0.9587 - recall: 0.8807 - roc_auc: 0.9985 - val_binary_accuracy: 0.9711 - val_loss: 0.0661 - val_pr_auc: 0.9740 - val_precision: 1.0000 - val_recall: 0.7047 - val_roc_auc: 0.9940 - learning_rate: 0.0010
# Epoch 8/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9882 - loss: 0.0279 - pr_auc: 0.9915 - precision: 0.9670 - recall: 0.9005 - roc_auc: 0.9991 - val_binary_accuracy: 0.9731 - val_loss: 0.0655 - val_pr_auc: 0.9731 - val_precision: 0.9821 - val_recall: 0.7383 - val_roc_auc: 0.9968 - learning_rate: 0.0010
# Epoch 9/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9898 - loss: 0.0286 - pr_auc: 0.9866 - precision: 0.9730 - recall: 0.9132 - roc_auc: 0.9979 - val_binary_accuracy: 0.9843 - val_loss: 0.0412 - val_pr_auc: 0.9753 - val_precision: 0.9139 - val_recall: 0.9262 - val_roc_auc: 0.9968 - learning_rate: 0.0010
# Epoch 10/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9897 - loss: 0.0254 - pr_auc: 0.9918 - precision: 0.9712 - recall: 0.9132 - roc_auc: 0.9991 - val_binary_accuracy: 0.9849 - val_loss: 0.0431 - val_pr_auc: 0.9755 - val_precision: 0.9375 - val_recall: 0.9060 - val_roc_auc: 0.9969 - learning_rate: 0.0010
# Epoch 11/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9870 - loss: 0.0332 - pr_auc: 0.9833 - precision: 0.9489 - recall: 0.9060 - roc_auc: 0.9973 - val_binary_accuracy: 0.9777 - val_loss: 0.0509 - val_pr_auc: 0.9842 - val_precision: 0.9915 - val_recall: 0.7785 - val_roc_auc: 0.9980 - learning_rate: 0.0010
# Epoch 12/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - binary_accuracy: 0.9916 - loss: 0.0222 - pr_auc: 0.9938 - precision: 0.9683 - recall: 0.9385 - roc_auc: 0.9993 - val_binary_accuracy: 0.9823 - val_loss: 0.0412 - val_pr_auc: 0.9774 - val_precision: 0.9420 - val_recall: 0.8725 - val_roc_auc: 0.9972 - learning_rate: 0.0010
# Epoch 13/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - binary_accuracy: 0.9849 - loss: 0.0333 - pr_auc: 0.9839 - precision: 0.9546 - recall: 0.8752 - roc_auc: 0.9984 - val_binary_accuracy: 0.9830 - val_loss: 0.0433 - val_pr_auc: 0.9762 - val_precision: 0.9301 - val_recall: 0.8926 - val_roc_auc: 0.9971 - learning_rate: 0.0010
# Epoch 14/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - binary_accuracy: 0.9915 - loss: 0.0249 - pr_auc: 0.9902 - precision: 0.9735 - recall: 0.9313 - roc_auc: 0.9992 - val_binary_accuracy: 0.9823 - val_loss: 0.0500 - val_pr_auc: 0.9743 - val_precision: 0.9552 - val_recall: 0.8591 - val_roc_auc: 0.9941 - learning_rate: 5.0000e-04
# Epoch 15/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9954 - loss: 0.0167 - pr_auc: 0.9968 - precision: 0.9944 - recall: 0.9548 - roc_auc: 0.9989 - val_binary_accuracy: 0.9836 - val_loss: 0.0480 - val_pr_auc: 0.9769 - val_precision: 0.9769 - val_recall: 0.8523 - val_roc_auc: 0.9944 - learning_rate: 5.0000e-04
# Epoch 16/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9959 - loss: 0.0138 - pr_auc: 0.9958 - precision: 0.9871 - recall: 0.9675 - roc_auc: 0.9997 - val_binary_accuracy: 0.9810 - val_loss: 0.0546 - val_pr_auc: 0.9763 - val_precision: 0.9918 - val_recall: 0.8121 - val_roc_auc: 0.9916 - learning_rate: 5.0000e-04
# Epoch 17/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9964 - loss: 0.0128 - pr_auc: 0.9972 - precision: 0.9944 - recall: 0.9656 - roc_auc: 0.9989 - val_binary_accuracy: 0.9830 - val_loss: 0.0400 - val_pr_auc: 0.9774 - val_precision: 0.9489 - val_recall: 0.8725 - val_roc_auc: 0.9916 - learning_rate: 5.0000e-04
# Epoch 18/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9962 - loss: 0.0130 - pr_auc: 0.9971 - precision: 0.9926 - recall: 0.9656 - roc_auc: 0.9989 - val_binary_accuracy: 0.9856 - val_loss: 0.0417 - val_pr_auc: 0.9772 - val_precision: 0.9379 - val_recall: 0.9128 - val_roc_auc: 0.9943 - learning_rate: 5.0000e-04
# Epoch 19/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9972 - loss: 0.0085 - pr_auc: 0.9991 - precision: 0.9926 - recall: 0.9765 - roc_auc: 0.9999 - val_binary_accuracy: 0.9803 - val_loss: 0.0603 - val_pr_auc: 0.9646 - val_precision: 0.9685 - val_recall: 0.8255 - val_roc_auc: 0.9819 - learning_rate: 5.0000e-04
# Epoch 20/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9980 - loss: 0.0081 - pr_auc: 0.9996 - precision: 0.9963 - recall: 0.9819 - roc_auc: 1.0000 - val_binary_accuracy: 0.9862 - val_loss: 0.0467 - val_pr_auc: 0.9748 - val_precision: 0.9776 - val_recall: 0.8792 - val_roc_auc: 0.9886 - learning_rate: 5.0000e-04
# Epoch 21/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9979 - loss: 0.0079 - pr_auc: 0.9993 - precision: 0.9927 - recall: 0.9837 - roc_auc: 0.9999 - val_binary_accuracy: 0.9843 - val_loss: 0.0421 - val_pr_auc: 0.9798 - val_precision: 0.9562 - val_recall: 0.8792 - val_roc_auc: 0.9948 - learning_rate: 5.0000e-04
# Epoch 22/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - binary_accuracy: 0.9980 - loss: 0.0079 - pr_auc: 0.9992 - precision: 0.9909 - recall: 0.9873 - roc_auc: 0.9999 - val_binary_accuracy: 0.9836 - val_loss: 0.0432 - val_pr_auc: 0.9739 - val_precision: 0.9697 - val_recall: 0.8591 - val_roc_auc: 0.9885 - learning_rate: 2.5000e-04
# Epoch 23/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9992 - loss: 0.0047 - pr_auc: 1.0000 - precision: 1.0000 - recall: 0.9910 - roc_auc: 1.0000 - val_binary_accuracy: 0.9830 - val_loss: 0.0528 - val_pr_auc: 0.9688 - val_precision: 0.9695 - val_recall: 0.8523 - val_roc_auc: 0.9851 - learning_rate: 2.5000e-04
# Epoch 24/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9990 - loss: 0.0049 - pr_auc: 1.0000 - precision: 1.0000 - recall: 0.9892 - roc_auc: 1.0000 - val_binary_accuracy: 0.9830 - val_loss: 0.0472 - val_pr_auc: 0.9741 - val_precision: 0.9695 - val_recall: 0.8523 - val_roc_auc: 0.9885 - learning_rate: 2.5000e-04
# Epoch 25/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - binary_accuracy: 0.9985 - loss: 0.0060 - pr_auc: 0.9996 - precision: 0.9945 - recall: 0.9892 - roc_auc: 1.0000 - val_binary_accuracy: 0.9862 - val_loss: 0.0368 - val_pr_auc: 0.9809 - val_precision: 0.9444 - val_recall: 0.9128 - val_roc_auc: 0.9949 - learning_rate: 2.5000e-04
# Epoch 26/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - binary_accuracy: 0.9987 - loss: 0.0054 - pr_auc: 0.9998 - precision: 0.9964 - recall: 0.9892 - roc_auc: 1.0000 - val_binary_accuracy: 0.9843 - val_loss: 0.0494 - val_pr_auc: 0.9705 - val_precision: 0.9771 - val_recall: 0.8591 - val_roc_auc: 0.9853 - learning_rate: 2.5000e-04
# Epoch 27/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - binary_accuracy: 0.9990 - loss: 0.0045 - pr_auc: 0.9999 - precision: 0.9964 - recall: 0.9928 - roc_auc: 1.0000 - val_binary_accuracy: 0.9843 - val_loss: 0.0427 - val_pr_auc: 0.9739 - val_precision: 0.9562 - val_recall: 0.8792 - val_roc_auc: 0.9885 - learning_rate: 2.5000e-04
# Epoch 28/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9985 - loss: 0.0059 - pr_auc: 0.9995 - precision: 0.9928 - recall: 0.9910 - roc_auc: 1.0000 - val_binary_accuracy: 0.9816 - val_loss: 0.0458 - val_pr_auc: 0.9712 - val_precision: 0.9618 - val_recall: 0.8456 - val_roc_auc: 0.9854 - learning_rate: 2.5000e-04
# Epoch 29/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9985 - loss: 0.0059 - pr_auc: 0.9998 - precision: 0.9964 - recall: 0.9873 - roc_auc: 1.0000 - val_binary_accuracy: 0.9843 - val_loss: 0.0418 - val_pr_auc: 0.9746 - val_precision: 0.9562 - val_recall: 0.8792 - val_roc_auc: 0.9886 - learning_rate: 2.5000e-04
# Epoch 30/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9987 - loss: 0.0042 - pr_auc: 0.9999 - precision: 0.9964 - recall: 0.9892 - roc_auc: 1.0000 - val_binary_accuracy: 0.9836 - val_loss: 0.0410 - val_pr_auc: 0.9755 - val_precision: 0.9697 - val_recall: 0.8591 - val_roc_auc: 0.9886 - learning_rate: 1.2500e-04
# Epoch 31/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9990 - loss: 0.0043 - pr_auc: 1.0000 - precision: 1.0000 - recall: 0.9892 - roc_auc: 1.0000 - val_binary_accuracy: 0.9849 - val_loss: 0.0457 - val_pr_auc: 0.9664 - val_precision: 0.9565 - val_recall: 0.8859 - val_roc_auc: 0.9820 - learning_rate: 1.2500e-04
# Epoch 32/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9990 - loss: 0.0055 - pr_auc: 0.9999 - precision: 0.9982 - recall: 0.9910 - roc_auc: 1.0000 - val_binary_accuracy: 0.9843 - val_loss: 0.0419 - val_pr_auc: 0.9751 - val_precision: 0.9562 - val_recall: 0.8792 - val_roc_auc: 0.9886 - learning_rate: 1.2500e-04
# Epoch 33/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9989 - loss: 0.0050 - pr_auc: 0.9998 - precision: 0.9964 - recall: 0.9910 - roc_auc: 1.0000 - val_binary_accuracy: 0.9849 - val_loss: 0.0522 - val_pr_auc: 0.9676 - val_precision: 0.9701 - val_recall: 0.8725 - val_roc_auc: 0.9822 - learning_rate: 1.2500e-04
# Training binary model for variant: M
# Epoch 1/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 9s 57ms/step - binary_accuracy: 0.9568 - loss: 0.2150 - pr_auc: 0.3621 - precision: 0.4615 - recall: 0.3305 - roc_auc: 0.8317 - val_binary_accuracy: 0.9750 - val_loss: 0.0721 - val_pr_auc: 0.8029 - val_precision: 1.0000 - val_recall: 0.3455 - val_roc_auc: 0.9453 - learning_rate: 0.0010
# Epoch 2/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9795 - loss: 0.0509 - pr_auc: 0.8321 - precision: 0.8391 - recall: 0.6186 - roc_auc: 0.9845 - val_binary_accuracy: 0.9792 - val_loss: 0.0479 - val_pr_auc: 0.8737 - val_precision: 0.9032 - val_recall: 0.5091 - val_roc_auc: 0.9667 - learning_rate: 0.0010
# Epoch 3/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - binary_accuracy: 0.9849 - loss: 0.0404 - pr_auc: 0.8948 - precision: 0.8942 - recall: 0.7161 - roc_auc: 0.9909 - val_binary_accuracy: 0.9743 - val_loss: 0.0644 - val_pr_auc: 0.8915 - val_precision: 0.6154 - val_recall: 0.8727 - val_roc_auc: 0.9900 - learning_rate: 0.0010
# Epoch 4/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9870 - loss: 0.0394 - pr_auc: 0.8991 - precision: 0.8966 - recall: 0.7712 - roc_auc: 0.9874 - val_binary_accuracy: 0.9847 - val_loss: 0.0425 - val_pr_auc: 0.8728 - val_precision: 0.8000 - val_recall: 0.8000 - val_roc_auc: 0.9751 - learning_rate: 0.0010
# Epoch 5/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9922 - loss: 0.0193 - pr_auc: 0.9742 - precision: 0.9401 - recall: 0.8644 - roc_auc: 0.9988 - val_binary_accuracy: 0.9903 - val_loss: 0.0303 - val_pr_auc: 0.9253 - val_precision: 0.8868 - val_recall: 0.8545 - val_roc_auc: 0.9949 - learning_rate: 0.0010
# Epoch 6/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9950 - loss: 0.0175 - pr_auc: 0.9830 - precision: 0.9726 - recall: 0.9025 - roc_auc: 0.9971 - val_binary_accuracy: 0.9903 - val_loss: 0.0346 - val_pr_auc: 0.9184 - val_precision: 0.9020 - val_recall: 0.8364 - val_roc_auc: 0.9859 - learning_rate: 0.0010
# Epoch 7/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9865 - loss: 0.0400 - pr_auc: 0.9004 - precision: 0.8624 - recall: 0.7966 - roc_auc: 0.9800 - val_binary_accuracy: 0.9820 - val_loss: 0.0422 - val_pr_auc: 0.9018 - val_precision: 0.7164 - val_recall: 0.8727 - val_roc_auc: 0.9933 - learning_rate: 0.0010
# Epoch 8/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9925 - loss: 0.0195 - pr_auc: 0.9714 - precision: 0.9251 - recall: 0.8898 - roc_auc: 0.9985 - val_binary_accuracy: 0.9854 - val_loss: 0.0348 - val_pr_auc: 0.9193 - val_precision: 0.7833 - val_recall: 0.8545 - val_roc_auc: 0.9949 - learning_rate: 0.0010
# Epoch 9/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9964 - loss: 0.0106 - pr_auc: 0.9914 - precision: 0.9654 - recall: 0.9449 - roc_auc: 0.9995 - val_binary_accuracy: 0.9861 - val_loss: 0.0599 - val_pr_auc: 0.8833 - val_precision: 1.0000 - val_recall: 0.6364 - val_roc_auc: 0.9443 - learning_rate: 0.0010
# Epoch 10/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - binary_accuracy: 0.9964 - loss: 0.0096 - pr_auc: 0.9948 - precision: 0.9864 - recall: 0.9237 - roc_auc: 0.9998 - val_binary_accuracy: 0.9903 - val_loss: 0.0366 - val_pr_auc: 0.9207 - val_precision: 0.9556 - val_recall: 0.7818 - val_roc_auc: 0.9708 - learning_rate: 5.0000e-04
# Epoch 11/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - binary_accuracy: 0.9981 - loss: 0.0051 - pr_auc: 0.9989 - precision: 0.9956 - recall: 0.9576 - roc_auc: 0.9999 - val_binary_accuracy: 0.9896 - val_loss: 0.0326 - val_pr_auc: 0.9231 - val_precision: 0.8846 - val_recall: 0.8364 - val_roc_auc: 0.9791 - learning_rate: 5.0000e-04
# Epoch 12/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - binary_accuracy: 0.9986 - loss: 0.0041 - pr_auc: 0.9992 - precision: 0.9957 - recall: 0.9703 - roc_auc: 1.0000 - val_binary_accuracy: 0.9903 - val_loss: 0.0300 - val_pr_auc: 0.9312 - val_precision: 0.8868 - val_recall: 0.8545 - val_roc_auc: 0.9877 - learning_rate: 5.0000e-04
# Epoch 13/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9986 - loss: 0.0037 - pr_auc: 0.9999 - precision: 1.0000 - recall: 0.9661 - roc_auc: 1.0000 - val_binary_accuracy: 0.9903 - val_loss: 0.0407 - val_pr_auc: 0.9107 - val_precision: 0.9362 - val_recall: 0.8000 - val_roc_auc: 0.9703 - learning_rate: 5.0000e-04
# Epoch 14/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9984 - loss: 0.0045 - pr_auc: 0.9992 - precision: 0.9913 - recall: 0.9703 - roc_auc: 1.0000 - val_binary_accuracy: 0.9903 - val_loss: 0.0355 - val_pr_auc: 0.9152 - val_precision: 0.9184 - val_recall: 0.8182 - val_roc_auc: 0.9706 - learning_rate: 5.0000e-04
# Epoch 15/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9995 - loss: 0.0026 - pr_auc: 0.9998 - precision: 0.9957 - recall: 0.9915 - roc_auc: 1.0000 - val_binary_accuracy: 0.9910 - val_loss: 0.0419 - val_pr_auc: 0.9161 - val_precision: 0.9375 - val_recall: 0.8182 - val_roc_auc: 0.9707 - learning_rate: 5.0000e-04
# Epoch 16/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9986 - loss: 0.0035 - pr_auc: 0.9998 - precision: 1.0000 - recall: 0.9661 - roc_auc: 1.0000 - val_binary_accuracy: 0.9889 - val_loss: 0.0391 - val_pr_auc: 0.9163 - val_precision: 0.8824 - val_recall: 0.8182 - val_roc_auc: 0.9706 - learning_rate: 5.0000e-04
# Epoch 17/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9986 - loss: 0.0032 - pr_auc: 0.9992 - precision: 0.9831 - recall: 0.9831 - roc_auc: 1.0000 - val_binary_accuracy: 0.9889 - val_loss: 0.0464 - val_pr_auc: 0.9089 - val_precision: 0.9333 - val_recall: 0.7636 - val_roc_auc: 0.9703 - learning_rate: 2.5000e-04
# Epoch 18/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9995 - loss: 0.0029 - pr_auc: 0.9999 - precision: 1.0000 - recall: 0.9873 - roc_auc: 1.0000 - val_binary_accuracy: 0.9896 - val_loss: 0.0455 - val_pr_auc: 0.9102 - val_precision: 0.9167 - val_recall: 0.8000 - val_roc_auc: 0.9705 - learning_rate: 2.5000e-04
# Epoch 19/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9990 - loss: 0.0027 - pr_auc: 0.9997 - precision: 1.0000 - recall: 0.9746 - roc_auc: 1.0000 - val_binary_accuracy: 0.9903 - val_loss: 0.0405 - val_pr_auc: 0.9139 - val_precision: 0.9184 - val_recall: 0.8182 - val_roc_auc: 0.9705 - learning_rate: 2.5000e-04
# Epoch 20/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9991 - loss: 0.0030 - pr_auc: 0.9996 - precision: 0.9915 - recall: 0.9873 - roc_auc: 1.0000 - val_binary_accuracy: 0.9903 - val_loss: 0.0448 - val_pr_auc: 0.9122 - val_precision: 0.9184 - val_recall: 0.8182 - val_roc_auc: 0.9706 - learning_rate: 2.5000e-04
# Training binary model for variant: W
# Epoch 1/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - binary_accuracy: 0.9624 - loss: 0.2902 - pr_auc: 0.6254 - precision: 0.7051 - recall: 0.6100 - roc_auc: 0.8928 - val_binary_accuracy: 0.9857 - val_loss: 0.0494 - val_pr_auc: 0.9175 - val_precision: 0.9155 - val_recall: 0.8125 - val_roc_auc: 0.9937 - learning_rate: 0.0010
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9833 - loss: 0.0487 - pr_auc: 0.9257 - precision: 0.9064 - recall: 0.7947 - roc_auc: 0.9894 - val_binary_accuracy: 0.9822 - val_loss: 0.0413 - val_pr_auc: 0.9432 - val_precision: 0.9821 - val_recall: 0.6875 - val_roc_auc: 0.9960 - learning_rate: 0.0010
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - binary_accuracy: 0.9865 - loss: 0.0360 - pr_auc: 0.9523 - precision: 0.9199 - recall: 0.8416 - roc_auc: 0.9949 - val_binary_accuracy: 0.9857 - val_loss: 0.0341 - val_pr_auc: 0.9625 - val_precision: 0.8391 - val_recall: 0.9125 - val_roc_auc: 0.9976 - learning_rate: 0.0010
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9898 - loss: 0.0273 - pr_auc: 0.9726 - precision: 0.9577 - recall: 0.8622 - roc_auc: 0.9978 - val_binary_accuracy: 0.9836 - val_loss: 0.0378 - val_pr_auc: 0.9457 - val_precision: 0.9118 - val_recall: 0.7750 - val_roc_auc: 0.9965 - learning_rate: 0.0010
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9889 - loss: 0.0321 - pr_auc: 0.9621 - precision: 0.9423 - recall: 0.8622 - roc_auc: 0.9901 - val_binary_accuracy: 0.9863 - val_loss: 0.0352 - val_pr_auc: 0.9479 - val_precision: 0.8846 - val_recall: 0.8625 - val_roc_auc: 0.9962 - learning_rate: 0.0010
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9923 - loss: 0.0204 - pr_auc: 0.9836 - precision: 0.9596 - recall: 0.9062 - roc_auc: 0.9988 - val_binary_accuracy: 0.9850 - val_loss: 0.0283 - val_pr_auc: 0.9647 - val_precision: 0.8537 - val_recall: 0.8750 - val_roc_auc: 0.9977 - learning_rate: 0.0010
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - binary_accuracy: 0.9940 - loss: 0.0186 - pr_auc: 0.9858 - precision: 0.9665 - recall: 0.9296 - roc_auc: 0.9989 - val_binary_accuracy: 0.9870 - val_loss: 0.0285 - val_pr_auc: 0.9687 - val_precision: 0.9841 - val_recall: 0.7750 - val_roc_auc: 0.9922 - learning_rate: 0.0010
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - binary_accuracy: 0.9973 - loss: 0.0087 - pr_auc: 0.9979 - precision: 0.9939 - recall: 0.9589 - roc_auc: 0.9999 - val_binary_accuracy: 0.9863 - val_loss: 0.0401 - val_pr_auc: 0.9603 - val_precision: 0.9688 - val_recall: 0.7750 - val_roc_auc: 0.9919 - learning_rate: 0.0010
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - binary_accuracy: 0.9944 - loss: 0.0135 - pr_auc: 0.9929 - precision: 0.9639 - recall: 0.9384 - roc_auc: 0.9995 - val_binary_accuracy: 0.9836 - val_loss: 0.0408 - val_pr_auc: 0.9509 - val_precision: 0.9516 - val_recall: 0.7375 - val_roc_auc: 0.9910 - learning_rate: 0.0010
# Epoch 10/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - binary_accuracy: 0.9956 - loss: 0.0120 - pr_auc: 0.9943 - precision: 0.9730 - recall: 0.9501 - roc_auc: 0.9996 - val_binary_accuracy: 0.9884 - val_loss: 0.0256 - val_pr_auc: 0.9739 - val_precision: 0.9565 - val_recall: 0.8250 - val_roc_auc: 0.9926 - learning_rate: 0.0010
# Epoch 11/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9947 - loss: 0.0126 - pr_auc: 0.9935 - precision: 0.9641 - recall: 0.9443 - roc_auc: 0.9995 - val_binary_accuracy: 0.9891 - val_loss: 0.0282 - val_pr_auc: 0.9734 - val_precision: 0.9848 - val_recall: 0.8125 - val_roc_auc: 0.9982 - learning_rate: 0.0010
# Epoch 12/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9959 - loss: 0.0094 - pr_auc: 0.9973 - precision: 0.9789 - recall: 0.9501 - roc_auc: 0.9998 - val_binary_accuracy: 0.9884 - val_loss: 0.0304 - val_pr_auc: 0.9735 - val_precision: 0.9565 - val_recall: 0.8250 - val_roc_auc: 0.9983 - learning_rate: 0.0010
# Epoch 13/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9974 - loss: 0.0060 - pr_auc: 0.9987 - precision: 0.9794 - recall: 0.9765 - roc_auc: 0.9999 - val_binary_accuracy: 0.9836 - val_loss: 0.0669 - val_pr_auc: 0.8979 - val_precision: 0.9516 - val_recall: 0.7375 - val_roc_auc: 0.9485 - learning_rate: 0.0010
# Epoch 14/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9974 - loss: 0.0069 - pr_auc: 0.9981 - precision: 0.9939 - recall: 0.9619 - roc_auc: 0.9999 - val_binary_accuracy: 0.9891 - val_loss: 0.0328 - val_pr_auc: 0.9531 - val_precision: 0.9211 - val_recall: 0.8750 - val_roc_auc: 0.9854 - learning_rate: 0.0010
# Epoch 15/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9986 - loss: 0.0042 - pr_auc: 0.9992 - precision: 0.9970 - recall: 0.9795 - roc_auc: 0.9999 - val_binary_accuracy: 0.9891 - val_loss: 0.0254 - val_pr_auc: 0.9744 - val_precision: 0.9103 - val_recall: 0.8875 - val_roc_auc: 0.9983 - learning_rate: 5.0000e-04
# Epoch 16/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9993 - loss: 0.0027 - pr_auc: 0.9999 - precision: 1.0000 - recall: 0.9883 - roc_auc: 1.0000 - val_binary_accuracy: 0.9898 - val_loss: 0.0271 - val_pr_auc: 0.9703 - val_precision: 0.9577 - val_recall: 0.8500 - val_roc_auc: 0.9925 - learning_rate: 5.0000e-04
# Epoch 17/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9993 - loss: 0.0015 - pr_auc: 1.0000 - precision: 0.9971 - recall: 0.9912 - roc_auc: 1.0000 - val_binary_accuracy: 0.9863 - val_loss: 0.0300 - val_pr_auc: 0.9665 - val_precision: 0.9167 - val_recall: 0.8250 - val_roc_auc: 0.9922 - learning_rate: 5.0000e-04
# Epoch 18/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.9986 - loss: 0.0052 - pr_auc: 0.9957 - precision: 0.9941 - recall: 0.9824 - roc_auc: 0.9998 - val_binary_accuracy: 0.9884 - val_loss: 0.0280 - val_pr_auc: 0.9624 - val_precision: 0.9200 - val_recall: 0.8625 - val_roc_auc: 0.9863 - learning_rate: 5.0000e-04
# Epoch 19/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - binary_accuracy: 0.9991 - loss: 0.0031 - pr_auc: 0.9998 - precision: 0.9970 - recall: 0.9883 - roc_auc: 1.0000 - val_binary_accuracy: 0.9904 - val_loss: 0.0275 - val_pr_auc: 0.9683 - val_precision: 0.9231 - val_recall: 0.9000 - val_roc_auc: 0.9923 - learning_rate: 5.0000e-04
# Epoch 20/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9988 - loss: 0.0032 - pr_auc: 0.9996 - precision: 0.9970 - recall: 0.9824 - roc_auc: 1.0000 - val_binary_accuracy: 0.9877 - val_loss: 0.0304 - val_pr_auc: 0.9651 - val_precision: 0.9079 - val_recall: 0.8625 - val_roc_auc: 0.9921 - learning_rate: 2.5000e-04
# Epoch 21/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - binary_accuracy: 0.9995 - loss: 0.0017 - pr_auc: 1.0000 - precision: 1.0000 - recall: 0.9912 - roc_auc: 1.0000 - val_binary_accuracy: 0.9891 - val_loss: 0.0298 - val_pr_auc: 0.9667 - val_precision: 0.9103 - val_recall: 0.8875 - val_roc_auc: 0.9922 - learning_rate: 2.5000e-04
# Epoch 22/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - binary_accuracy: 0.9998 - loss: 0.0017 - pr_auc: 1.0000 - precision: 1.0000 - recall: 0.9971 - roc_auc: 1.0000 - val_binary_accuracy: 0.9870 - val_loss: 0.0322 - val_pr_auc: 0.9588 - val_precision: 0.9296 - val_recall: 0.8250 - val_roc_auc: 0.9861 - learning_rate: 2.5000e-04
# Epoch 23/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - binary_accuracy: 0.9991 - loss: 0.0023 - pr_auc: 0.9999 - precision: 0.9970 - recall: 0.9883 - roc_auc: 1.0000 - val_binary_accuracy: 0.9884 - val_loss: 0.0290 - val_pr_auc: 0.9669 - val_precision: 0.9315 - val_recall: 0.8500 - val_roc_auc: 0.9923 - learning_rate: 2.5000e-04

# %%
multilabel_results = evaluate_models_for_variants(multilabel_models, variants, "multilabel", DATASET_LABEL)
binary_results = evaluate_models_for_variants(binary_models, variants, "binary", DATASET_LABEL)
comparison_results = pd.concat([multilabel_results.assign(task="multilabel"), binary_results.assign(task="binary")], ignore_index=True)
display(comparison_results[["task", "Model", "precision", "recall", "f1-score", "support"]])
# Out:
# ==================================================
# --- Evaluation for: Multilabel normal MFCC-40 ---
# ==================================================
#
#                    precision    recall  f1-score   support
#
# ArtificialSignals       0.98      0.82      0.89       214
#  BigPassengerShip       1.00      0.05      0.09        22
#             Cargo       0.50      0.06      0.11        49
#          FishBoat       0.92      0.78      0.85        46
#         GreenCity       0.95      0.60      0.74        98
#            KaiYan       1.00      0.33      0.50        21
#           KaiYuan       0.75      0.56      0.64       257
#         MotorBoat       0.88      0.27      0.41        26
#               No7       0.90      0.50      0.64       143
#        PoliceBoat       1.00      0.05      0.09        22
#           QianDao       0.88      0.67      0.76       680
#         SpeedBoat       0.84      0.83      0.83       836
#           TheEarl       0.95      0.88      0.91       103
#         TheKnight       0.95      0.65      0.77        62
#               UUV       0.97      0.82      0.89       200
#           Unknown       0.84      0.53      0.65        40
#          WorkShip       1.00      0.56      0.72        41
#
#         micro avg       0.88      0.70      0.78      2860
#         macro avg       0.90      0.53      0.62      2860
#      weighted avg       0.88      0.70      0.76      2860
#       samples avg       0.66      0.60      0.61      2860
#
# Micro F1: 0.7760670434613136
# Macro F1: 0.6167259393245664
# Samples F1: 0.6092764702943086
#
# ==================================================
# --- Evaluation for: Multilabel M MFCC-40 ---
# ==================================================
#
#                    precision    recall  f1-score   support
#
# ArtificialSignals       0.94      0.78      0.85        99
#  BigPassengerShip       1.00      0.14      0.25        28
#             Cargo       0.70      0.17      0.27        42
#          FishBoat       0.83      0.45      0.59        33
#         GreenCity       0.91      0.48      0.63       111
#            KaiYan       1.00      0.30      0.46        27
#           KaiYuan       0.77      0.57      0.66       238
#         MotorBoat       1.00      0.52      0.69        21
#               No7       1.00      0.27      0.42        78
#        PoliceBoat       0.50      0.07      0.12        15
#           QianDao       0.83      0.81      0.82       671
#         SpeedBoat       0.86      0.80      0.83       799
#           TheEarl       0.97      0.78      0.86       118
#         TheKnight       0.78      0.53      0.63        60
#               UUV       0.97      0.73      0.83        88
#           Unknown       0.78      0.19      0.30        37
#          WorkShip       0.96      0.75      0.84        32
#
#         micro avg       0.86      0.69      0.77      2497
#         macro avg       0.87      0.49      0.59      2497
#      weighted avg       0.86      0.69      0.75      2497
#       samples avg       0.64      0.60      0.60      2497
#
# Micro F1: 0.767426421774729
# Macro F1: 0.591347430576437
# Samples F1: 0.601406625948547
#
# ==================================================
# --- Evaluation for: Multilabel W MFCC-40 ---
# ==================================================
#
#                    precision    recall  f1-score   support
#
# ArtificialSignals       0.98      0.76      0.86       113
#  BigPassengerShip       1.00      0.19      0.33        36
#             Cargo       0.73      0.28      0.40        40
#          FishBoat       1.00      1.00      1.00        16
#         GreenCity       0.96      0.48      0.64       107
#            KaiYan       1.00      0.53      0.69        17
#           KaiYuan       0.83      0.44      0.58       246
#         MotorBoat       0.00      0.00      0.00         0
#               No7       0.86      0.46      0.60       110
#        PoliceBoat       0.67      0.18      0.29        11
#           QianDao       0.88      0.79      0.83       651
#         SpeedBoat       0.88      0.85      0.87       821
#           TheEarl       0.95      0.80      0.86       108
#         TheKnight       0.67      0.63      0.65        60
#               UUV       0.96      0.71      0.81       102
#           Unknown       0.86      0.14      0.24        43
#          WorkShip       0.97      0.71      0.82        45
#
#         micro avg       0.88      0.71      0.79      2526
#         macro avg       0.83      0.53      0.62      2526
#      weighted avg       0.88      0.71      0.77      2526
#       samples avg       0.66      0.60      0.61      2526
#
# Micro F1: 0.7860281195079086
# Macro F1: 0.6153522274243033
# Samples F1: 0.6124772313296905
#
# ==================================================
# --- Evaluation for: Binary normal MFCC-40 ---
# ==================================================
#
#               precision    recall  f1-score   support
#
#       No UUV       0.99      1.00      0.99      1706
#          UUV       0.96      0.93      0.94       200
#
#     accuracy                           0.99      1906
#    macro avg       0.98      0.96      0.97      1906
# weighted avg       0.99      0.99      0.99      1906
#
#
# ==================================================
# --- Evaluation for: Binary M MFCC-40 ---
# ==================================================
#
#               precision    recall  f1-score   support
#
#       No UUV       0.99      1.00      1.00      1713
#          UUV       0.92      0.90      0.91        88
#
#     accuracy                           0.99      1801
#    macro avg       0.96      0.95      0.95      1801
# weighted avg       0.99      0.99      0.99      1801
#
#
# ==================================================
# --- Evaluation for: Binary W MFCC-40 ---
# ==================================================
#
#               precision    recall  f1-score   support
#
#       No UUV       0.99      1.00      0.99      1728
#          UUV       0.96      0.86      0.91       102
#
#     accuracy                           0.99      1830
#    macro avg       0.97      0.93      0.95      1830
# weighted avg       0.99      0.99      0.99      1830
#          task                      Model  precision    recall  f1-score  \
# 0  multilabel  Multilabel normal MFCC-40   0.970588  0.825000  0.891892
# 1  multilabel       Multilabel M MFCC-40   0.969697  0.727273  0.831169
# 2  multilabel       Multilabel W MFCC-40   0.960000  0.705882  0.813559
# 3      binary      Binary normal MFCC-40   0.963542  0.925000  0.943878
# 4      binary           Binary M MFCC-40   0.918605  0.897727  0.908046
# 5      binary           Binary W MFCC-40   0.956522  0.862745  0.907216
#
#    support
# 0    200.0
# 1     88.0
# 2    102.0
# 3    200.0
# 4     88.0
# 5    102.0

# %%
save_dir = save_keras_artifacts(f"/content/saved_artifacts/mlp_{DATASET_KEY}", DATASET_KEY, multilabel_models, binary_models, multilabel_histories, binary_histories, multilabel_results, binary_results)
comparison_results.to_csv(save_dir / f"mlp_comparison_{DATASET_KEY}.csv", index=False)
archive_path = zip_artifacts(save_dir, f"/content/mlp_models_and_results_{DATASET_KEY}.zip")
files.download(str(archive_path))
